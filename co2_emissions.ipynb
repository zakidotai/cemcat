# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('crystalline_composition_gpt4_with_pii_tid_dates.csv')

# %%
df['year'] = df.date.apply(lambda x: x[:4])
# df.year.value_counts()
